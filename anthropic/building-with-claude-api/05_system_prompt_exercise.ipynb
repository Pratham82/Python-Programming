# %%
# import helpers

from helpers import add_user_message, chat

# %%
messages = []


add_user_message(
  messages,
  "Write a python function that checks a string for duplicate character"
)

answer = chat(messages)

print(answer)
# Out:
# Here are several Python functions to check for duplicate characters in a string:
#
# ## Method 1: Simple boolean check (returns True/False)
#
# ```python
# def has_duplicate_chars(s):
#     """
#     Check if a string has duplicate characters.
#
#     Args:
#         s (str): Input string
#
#     Returns:
#         bool: True if duplicates exist, False otherwise
#     """
#     return len(s) != len(set(s))
#
# # Example usage
# print(has_duplicate_chars("hello"))     # True (l appears twice)
# print(has_duplicate_chars("world"))     # True (l appears twice)
# print(has_duplicate_chars("python"))    # False (no duplicates)
# ```
#
# ## Method 2: Using a loop with set tracking
#
# ```python
# def has_duplicate_chars_loop(s):
#     """
#     Check if a string has duplicate characters using a loop.
#
#     Args:
#         s (str): Input string
#
#     Returns:
#         bool: True if duplicates exist, False otherwise
#     """
#     seen = set()
#     for char in s:
# ...

# %%
# With system prompt

messages = []


add_user_message(
  messages,
  "Write a python function that checks a string for duplicate character"
)

concise_prompt= "Make the answer/output concise as possible and keep it to the point"

system="You are a python engineer who write very concise and clean code"

answer = chat(messages, system=concise_prompt)

print(answer)
# Out:
# Here are a few Python functions to check for duplicate characters in a string:
#
# ## Method 1: Using set (most concise)
# ```python
# def has_duplicates(s):
#     return len(s) != len(set(s))
# ```
#
# ## Method 2: Using dictionary to count occurrences
# ```python
# def has_duplicates(s):
#     char_count = {}
#     for char in s:
#         if char in char_count:
#             return True
#         char_count[char] = 1
#     return False
# ```
#
# ## Method 3: Return which characters are duplicated
# ```python
# def find_duplicates(s):
#     seen = set()
#     duplicates = set()
#     for char in s:
#         if char in seen:
#             duplicates.add(char)
#         else:
#             seen.add(char)
#     return list(duplicates)
# ```
#
# ## Usage examples:
# ```python
# # Method 1 & 2
# print(has_duplicates("hello"))     # True
# print(has_duplicates("world"))     # True
# print(has_duplicates("python"))    # False
#
# # Method 3
# print(find_duplicates("hello"))    # ['l']
# ...

# %%
# With system prompt

messages = []


add_user_message(
  messages,
  "Write a python function that checks a string for duplicate character"
)

system="You are a python engineer who write very concise and clean code"

answer = chat(messages, system=system)

print(answer)
# Out:
# ```python
# def has_duplicates(s):
#     return len(s) != len(set(s))
# ```
#
# This function converts the string to a set (which removes duplicates) and compares the lengths. If they differ, duplicates exist.
#
# Alternative version that returns the duplicate characters:
#
# ```python
# def find_duplicates(s):
#     seen = set()
#     return {char for char in s if char in seen or seen.add(char)}
# ```
